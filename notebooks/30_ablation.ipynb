# %% [markdown]
# # 30 · Ablation
#
# Runs one of the experiment's named evaluations: several models scored on **one shared
# evaluation set**, so the comparison is about training data, not about different test sets.
#
# Each model is guarded separately against its own training pairs, so a model that saw any
# of these sentences cannot silently contribute a row.

# %%
EXPERIMENT = "baseline"
EVALUATION = "domain-shift"     # declared in experiments/baseline.toml

# %%
from qomlaq.pipeline import run_evaluation
from qomlaq.report import ablation_table

records = run_evaluation(EXPERIMENT, EVALUATION)
ablation_table(records)
